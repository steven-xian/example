# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

plt.close("all")

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2022", periods=1000))

ts = ts.cumsum()
# print(ts)
ts.plot()
# Out:
# <AxesSubplot: >

# %%
print("ts")
print(ts)
cum = ts.cumsum()
print("cumsum")
print(cum)
# Out:
# ts
# 2022-01-01    -0.191334
# 2022-01-02     0.834842
# 2022-01-03     0.464071
# 2022-01-04     1.687049
# 2022-01-05     2.462541
#                 ...
# 2024-09-22   -46.568127
# 2024-09-23   -46.382202
# 2024-09-24   -44.964572
# 2024-09-25   -46.335516
# 2024-09-26   -46.116974
# Freq: D, Length: 1000, dtype: float64
# cumsum
# 2022-01-01       -0.191334
# 2022-01-02        0.643508
# 2022-01-03        1.107578
# 2022-01-04        2.794627
# 2022-01-05        5.257168
#                   ...
# 2024-09-22   -28847.981908
# 2024-09-23   -28894.364110
# 2024-09-24   -28939.328682
# 2024-09-25   -28985.664198
# 2024-09-26   -29031.781172
# Freq: D, Length: 1000, dtype: float64

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list("ABCD"))
df = df.cumsum()
print(df)
plt.figure()
df.plot()
# Out:
#                     A          B          C          D
# 2022-01-01  -0.435185  -0.865367   0.241919  -1.298496
# 2022-01-02  -0.706231  -0.550150  -0.295141  -1.650003
# 2022-01-03  -1.321790  -0.919002  -2.005643  -2.467061
# 2022-01-04  -1.228359  -2.451108  -2.053015  -1.882567
# 2022-01-05  -0.695931  -2.396624  -1.310887   0.063310
# ...               ...        ...        ...        ...
# 2024-09-22 -53.801982 -50.818506 -48.455773 -18.448070
# 2024-09-23 -54.712253 -49.421788 -48.486760 -17.283353
# 2024-09-24 -53.647254 -50.967503 -47.533967 -15.971248
# 2024-09-25 -53.561469 -51.661872 -45.229744 -13.056193
# 2024-09-26 -54.820426 -52.596617 -44.884879 -14.911282
#
# [1000 rows x 4 columns]
# <AxesSubplot: >

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=['B', 'C']).cumsum()

# print(df3)
print(len(df))
df3["A"] = pd.Series(list(range(len(df))))
print(df3["A"])

df3.plot(x="A", y=["B", "C"])
# Out:
# 1000
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 995    995
# 996    996
# 997    997
# 998    998
# 999    999
# Name: A, Length: 1000, dtype: int64
# <AxesSubplot: xlabel='A'>

# %%
print(df)

plt.figure()
df.iloc[4].plot(kind="bar")
# Out:
#                     A          B          C         D
# 2022-01-01   0.186707   0.655217  -0.489772 -0.329963
# 2022-01-02   0.895832  -0.117739  -1.397588 -1.723549
# 2022-01-03   0.710670   0.798963  -1.000001 -1.200878
# 2022-01-04   2.269102  -1.651550  -0.726612 -0.617229
# 2022-01-05   1.082643  -1.843126  -1.384569 -1.582298
# ...               ...        ...        ...       ...
# 2024-09-22  11.748917 -54.504744  38.296154 -2.378725
# 2024-09-23  10.773007 -54.805464  37.959026 -1.766561
# 2024-09-24  10.521765 -54.511239  35.859472 -2.799366
# 2024-09-25  10.102429 -54.654203  36.511235 -3.388601
# 2024-09-26  10.878487 -54.741716  37.336836 -2.354934
#
# [1000 rows x 4 columns]
# <AxesSubplot:>

# %%
plt.figure()

df.iloc[4].plot.bar()
plt.axhline(0, color="k")

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])
print(df2)
df2.plot.bar()
# Out:
#           a         b         c         d
# 0  0.161851  0.122928  0.690957  0.519078
# 1  0.364417  0.549051  0.351125  0.349306
# 2  0.766972  0.807044  0.905313  0.601866
# 3  0.845167  0.125967  0.238242  0.474126
# 4  0.669662  0.980465  0.711391  0.675991
# 5  0.104975  0.105554  0.975822  0.033021
# 6  0.571788  0.710097  0.279568  0.498785
# 7  0.972123  0.269512  0.322583  0.545809
# 8  0.149540  0.011406  0.602509  0.908891
# 9  0.972622  0.627803  0.366792  0.721481
# <AxesSubplot: >

# %%
print(df)
df.plot(subplots=True, figsize=(8,8))
# Out:
#                     A          B          C          D
# 2022-01-01  -0.435185  -0.865367   0.241919  -1.298496
# 2022-01-02  -0.706231  -0.550150  -0.295141  -1.650003
# 2022-01-03  -1.321790  -0.919002  -2.005643  -2.467061
# 2022-01-04  -1.228359  -2.451108  -2.053015  -1.882567
# 2022-01-05  -0.695931  -2.396624  -1.310887   0.063310
# ...               ...        ...        ...        ...
# 2024-09-22 -53.801982 -50.818506 -48.455773 -18.448070
# 2024-09-23 -54.712253 -49.421788 -48.486760 -17.283353
# 2024-09-24 -53.647254 -50.967503 -47.533967 -15.971248
# 2024-09-25 -53.561469 -51.661872 -45.229744 -13.056193
# 2024-09-26 -54.820426 -52.596617 -44.884879 -14.911282
#
# [1000 rows x 4 columns]
# array([<AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >],
#       dtype=object)

# %%
df["A"].plot()
df["B"].plot(secondary_y=True, style="g")
# Out:
# <AxesSubplot: >

# %%
plt.figure()

ax = df.plot(secondary_y=["A", "B"])
ax.set_ylabel("CD scale")
ax.right_ax.set_ylabel("AB scale")
# Out:
# Text(0, 0.5, 'AB scale')

# %%
plt.figure()

df.plot(secondary_y=["A", "B"], mark_right=False)
# Out:
# <AxesSubplot: >

# %%
plt.figure()
df["A"].plot()
# Out:
# <AxesSubplot: >

# %%
plt.figure()
df["A"].plot(x_compat=True)
# Out:
# <AxesSubplot: >

# %%
plt.figure()

with pd.plotting.plot_params.use("x_compat", True):
    df["A"].plot(color="r")
    df["B"].plot(color="g")
    df["C"].plot(color="b")

# %%
df.plot(subplots=True, layout=(2, 3), figsize=(6, 6), sharex=False)
# Out:
# array([[<AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >],
#        [<AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >]], dtype=object)

# %%
df.plot(subplots=True, layout=(2, -1), figsize=(6, 6), sharex=False)
# Out:
# array([[<AxesSubplot: >, <AxesSubplot: >],
#        [<AxesSubplot: >, <AxesSubplot: >]], dtype=object)

# %%
fig, axes = plt.subplots(4, 4, figsize=(9, 9))
plt.subplots_adjust(wspace=0.5, hspace=0.5)

target1 = [axes[0][0], axes[1][1], axes[2][2], axes[3][3]]
target2 = [axes[3][0], axes[2][1], axes[1][2], axes[0][3]]

df.plot(subplots=True, ax=target1, legend=False, sharex=False, sharey=False)
(-df).plot(subplots=True, ax=target2, legend=False, sharex=False, sharey=False)
# Out:
# array([<AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >],
#       dtype=object)
