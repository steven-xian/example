# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

plt.close("all")
# Out:
# Running cells with 'Python 3.10.8 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/opt/python@3.10/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2022", periods=1000))

ts = ts.cumsum()
# print(ts)
ts.plot()
# Out:
# <AxesSubplot:>

# %%
print("ts")
print(ts)
cum = ts.cumsum()
print("cumsum")
print(cum)
# Out:
# ts
# 2022-01-01    0.552409
# 2022-01-02   -1.154080
# 2022-01-03   -0.675352
# 2022-01-04    3.021240
# 2022-01-05   -0.000600
#                 ...
# 2024-09-22   -0.971966
# 2024-09-23   -1.543012
# 2024-09-24    1.293935
# 2024-09-25   -0.105360
# 2024-09-26    1.584359
# Freq: D, Length: 1000, dtype: float64
# cumsum
# 2022-01-01     0.552409
# 2022-01-02    -0.601671
# 2022-01-03    -1.277023
# 2022-01-04     1.744217
# 2022-01-05     1.743617
#                 ...
# 2024-09-22    15.166973
# 2024-09-23    13.623961
# 2024-09-24    14.917897
# 2024-09-25    14.812536
# 2024-09-26    16.396895
# Freq: D, Length: 1000, dtype: float64

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list("ABCD"))
df = df.cumsum()
print(df)
plt.figure()
df.plot()
# Out:
#                     A          B          C         D
# 2022-01-01   0.186707   0.655217  -0.489772 -0.329963
# 2022-01-02   0.895832  -0.117739  -1.397588 -1.723549
# 2022-01-03   0.710670   0.798963  -1.000001 -1.200878
# 2022-01-04   2.269102  -1.651550  -0.726612 -0.617229
# 2022-01-05   1.082643  -1.843126  -1.384569 -1.582298
# ...               ...        ...        ...       ...
# 2024-09-22  11.748917 -54.504744  38.296154 -2.378725
# 2024-09-23  10.773007 -54.805464  37.959026 -1.766561
# 2024-09-24  10.521765 -54.511239  35.859472 -2.799366
# 2024-09-25  10.102429 -54.654203  36.511235 -3.388601
# 2024-09-26  10.878487 -54.741716  37.336836 -2.354934
#
# [1000 rows x 4 columns]
# <AxesSubplot:>

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=['B', 'C']).cumsum()

# print(df3)
print(len(df))
df3["A"] = pd.Series(list(range(len(df))))
print(df3["A"])

df3.plot(x="A", y=["B", "C"])
# Out:
# 1000
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 995    995
# 996    996
# 997    997
# 998    998
# 999    999
# Name: A, Length: 1000, dtype: int64
# <AxesSubplot:xlabel='A'>

# %%
print(df)

plt.figure()
df.iloc[4].plot(kind="bar")
# Out:
#                     A          B          C         D
# 2022-01-01   0.186707   0.655217  -0.489772 -0.329963
# 2022-01-02   0.895832  -0.117739  -1.397588 -1.723549
# 2022-01-03   0.710670   0.798963  -1.000001 -1.200878
# 2022-01-04   2.269102  -1.651550  -0.726612 -0.617229
# 2022-01-05   1.082643  -1.843126  -1.384569 -1.582298
# ...               ...        ...        ...       ...
# 2024-09-22  11.748917 -54.504744  38.296154 -2.378725
# 2024-09-23  10.773007 -54.805464  37.959026 -1.766561
# 2024-09-24  10.521765 -54.511239  35.859472 -2.799366
# 2024-09-25  10.102429 -54.654203  36.511235 -3.388601
# 2024-09-26  10.878487 -54.741716  37.336836 -2.354934
#
# [1000 rows x 4 columns]
# <AxesSubplot:>

# %%
plt.figure()

df.iloc[4].plot.bar()
plt.axhline(0, color="k")

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])
print(df2)
df2.plot.bar()

# %%
print(df)
df.plot(subplots=True, figsize=(6,6))
# Out:
#                     A          B          C         D
# 2022-01-01   0.186707   0.655217  -0.489772 -0.329963
# 2022-01-02   0.895832  -0.117739  -1.397588 -1.723549
# 2022-01-03   0.710670   0.798963  -1.000001 -1.200878
# 2022-01-04   2.269102  -1.651550  -0.726612 -0.617229
# 2022-01-05   1.082643  -1.843126  -1.384569 -1.582298
# ...               ...        ...        ...       ...
# 2024-09-22  11.748917 -54.504744  38.296154 -2.378725
# 2024-09-23  10.773007 -54.805464  37.959026 -1.766561
# 2024-09-24  10.521765 -54.511239  35.859472 -2.799366
# 2024-09-25  10.102429 -54.654203  36.511235 -3.388601
# 2024-09-26  10.878487 -54.741716  37.336836 -2.354934
#
# [1000 rows x 4 columns]
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)
